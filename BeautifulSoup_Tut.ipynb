# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
html = requests.get("https://www.ibm.com/uk-en").text

# %%
html
# Out:
# ' \n<!DOCTYPE HTML>\n\n<html lang="en">\n<head>\r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n      \r\n    \r\n    \r\n    \r\n    \r\n    <meta charset="UTF-8"/>\r\n    <meta name="languageCode" content="en"/>\r\n    <meta name="countryCode" content="uk"/>\r\n    <meta name="searchTitle" content="IBM"/>\r\n    <meta name="focusArea" content="Cross IBM SDRs"/>\r\n    <meta name=\'primaryTaxonomyEn\' content="IBM"/>\r\n    <meta name="siteSection" content="home"/>\r\n    <meta name="primaryTopic" content="IBM"/>\r\n    <meta name="productName"/>\r\n    <meta name="pageType"/>\r\n    <title>IBM</title>\r\n      <meta name="content-page-ref" content="eROxip4tByGTXXkYPHZou1dx5K8QGjzlFv7gvxgIGdmXdpCWq8mPAxUAd36QHdh0uX5DLAELN8kcObodQWtduQ"/>\n<script defer="defer" type="text/javascript" src="https://rum.hlx.page/.rum/@adobe/helix-rum-js@%5E2/dist/micro.js" data-routing="program=131558,environment=1281329,tier=publish"></script>\n<link rel="icon" sizes="16x16" href="/content/d
# ...

# %%
s = BeautifulSoup(html)

# %%
s.find_all('img')
# Out:
# [<img alt="Illustration with graphic elements related to technology, user interface, and digital innovation, including graphics, icons, and design elements in shades of blue" class="cmp-image__image" height="1536" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/bb4y_5x4?ts=1772046852563&amp;dpr=off" srcset="..." title="Illustration of digital tools and activities" width="1920"/>,
#  <img alt="3D render of several tiles forming a globe" class="cmp-image__image" height="2161" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/tii_4_5000x8888?ts=1772046344938&amp;dpr=off" srcset="..." title="Abstract digital sphere with glowing blue and red lines" width="3840"/>,
# ...

# %%
for link in s.find_all('a',href=True):
    print(link.get('href'))
# Out:
# https://www.ibm.com/products/offers-and-discounts#additional-payment-options?lnk=hpls1uk
# https://www.ibm.com/new/announcements/your-checkout-your-choice-ibm-expands-global-payment-options?lnk=hpls2uk
# https://uk.newsroom.ibm.com/ibm-2026-x-force-threat-index?lnk=hprc1uk
# https://www.ibm.com/case-studies/british-sugar?lnk=hprc2uk
# https://www.ibm.com/products/aspera?lnk=hprc3uk
# https://www.ibm.com/products/webmethods-hybrid-integration?lnk=hprc4uk
# https://www.ibm.com/case-studies/avid-solutions-international?lnk=hpcs1us
# https://www.ibm.com/case-studies/scuderia-ferrari?lnk=hpcs2us
# https://www.ibm.com/case-studies/pfizer?lnk=hpcs3us
# https://www.ibm.com/software?lnk=hpfp1us
# https://www.ibm.com/solutions/ai-agents?lnk=hpfp2us
# https://www.ibm.com/solutions/data-and-ai?lnk=hpfp3us
# https://www.ibm.com/solutions/automation?lnk=hpfp4us
# https://www.ibm.com/solutions/hybrid-cloud?lnk=hpfp5us
# https://www.ibm.com/solutions/ai-models?lnk=hpfp6us
# ...

# %%
for img in s.find_all('img'):
    print(img.get('src'))
# Out:
# https://assets.ibm.com/is/image/ibm/bb4y_5x4?ts=1772046852563&dpr=off
# https://assets.ibm.com/is/image/ibm/tii_4_5000x8888?ts=1772046344938&dpr=off
# https://assets.ibm.com/is/image/ibm/improve-business-success?ts=1772046783668&dpr=off
# https://assets.ibm.com/is/image/ibm/aspera_object-storage-in-white-container_1x1_padding?ts=1772046654291&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm-webmethods-hybrid-integration-960x540-16_9?ts=1772046720920&dpr=off
# https://assets.ibm.com/is/image/ibm/avid-solutions-leadspace?ts=1769690471438&dpr=off
# https://assets.ibm.com/is/image/ibm/f678_still_f06_v10_zyn_4096x4096?ts=1770036072957&dpr=off
# https://assets.ibm.com/is/image/ibm/pfizer_thumb?ts=1769025609471&dpr=off
# https://assets.ibm.com/is/image/ibm/watson-discovery_eye-connection_1x1_padding?ts=1768982912247&dpr=off

# %%
html = requests.get('https://www.google.com/').text

# %%
s = BeautifulSoup(html)

# %%
s.find_all(href=True)
# Out:
# [<a class="gb1" href="https://www.google.com/imghp?hl=ar&amp;tab=wi">صور</a>,
#  <a class="gb1" href="https://maps.google.com.sa/maps?hl=ar&amp;tab=wl">خرائط Google</a>,
#  <a class="gb1" href="https://play.google.com/?hl=ar&amp;tab=w8">Play</a>,
#  <a class="gb1" href="https://www.youtube.com/?tab=w1">YouTube</a>,
#  <a class="gb1" href="https://news.google.com/?tab=wn">الأخبار</a>,
#  <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a>,
#  <a class="gb1" href="https://drive.google.com/?tab=wo">Drive</a>,
#  <a class="gb1" href="https://www.google.com.sa/intl/ar/about/products?tab=wh" style="text-decoration:none"><u>المزيد</u> »</a>,
#  <a class="gb4" href="http://www.google.com.sa/history/optout?hl=ar">سِجل بحث الويب</a>,
#  <a class="gb4" href="/preferences?hl=ar">الإعدادات</a>,
#  <a class="gb4" href="https://accounts.google.com/ServiceLogin?hl=ar&amp;passive=true&amp;continue=https://www.google.com/&amp;ec=GAZAAQ" id="gb_70" target="_top">تسجيل الدخول</a>,
# ...

# %%
s.find_all('img')
# Out:
# [<img alt="Google" height="92" id="hplogo" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" width="272"/>,
#  <img alt="" data-script-url="/textinputassistant/13/ar_tia.js" height="23" id="tsuid_viSzaaz-CsO8vr0Pjq_4wAI_1" src="/textinputassistant/tia.png" style="position:absolute;cursor:pointer;left:5px;top:4px;z-index:300" width="27"/>]

# %%
html = requests.get('https://www.extra.com/ar-sa/').text

# %%
s = BeautifulSoup(html)

# %%
html
# Out:
# '<!DOCTYPE html>\n<html lang="ar"  dir="rtl" class="rtl sa master-tag-check">\n<head>\n\n\t<title>\n\t\tتسوق جوالات, أجهزة منزلية, تلفزيونات والمزيد - إكسترا  </title>\n\n\t\n\t<meta http-equiv="x-dns-prefetch-control" content="on">\n  <meta name="robots" content="max-image-preview:large">\n\n\t<link rel="preconnect" href="https://media.extra.com" crossorigin>\n\t\t<link rel="preconnect" href="https://api.extra.com" crossorigin>\n\t\t<link rel="preconnect" href="https://cdn.extra.com" crossorigin>\n\t\t<link rel="preconnect" href="https://cdn.mxpnl.com" crossorigin>\n\t\t<link rel="preconnect" href="https://libraries.unbxdapi.com" crossorigin>\n\t\t<link rel="dns-prefetch" href="https://recs.richrelevance.com/rrserver">\n\t\t<link rel="dns-prefetch" href="https://c1.adis.ws">\n\t\t<link rel="dns-prefetch" href="https://cdn.mxpnl.com">\n\t\t<link rel="dns-prefetch" href="https://assets.emarsys.net">\n\t\t<link rel="dns-prefetch" href="https://www.googletagmanager.com">\n\t\t<link rel=
# ...

# %%
s.find_all('img')
# Out:
# [<img alt="extra.com" src="https://cdn.extra.com/hybris/new_ui_ux/logo/eXtra-logo.svg" title="extra.com"/>,
#  <img alt="first hot deal" src="https://cdn.extra.com/hybris/static/assets/prod/202603101550/_ui/responsive/theme-extra/images/spacer_image.gif"/>,
#  <img alt="second hot deal" src="https://cdn.extra.com/hybris/static/assets/prod/202603101550/_ui/responsive/theme-extra/images/spacer_image.gif"/>,
#  <img alt="Jood" src="https://cdn.extra.com/hybris/static/assets/prod/202603101550/_ui/responsive/theme-extra/images/jood/jood-logo.svg"/>,
#  <img alt="بسيطة" class="dropdown-image" loading="lazy" src="https://cdn.extra.com/hybris/static/assets/prod/202603101550/_ui/responsive/theme-extra/images/baseeta/baseeta-logo-ar.png"/>,
#  <img alt="خدمات اكسترا" class="dropdown-image" loading="lazy" src="https://cdn.extra.com/hybris/static/assets/prod/202603101550/_ui/responsive/theme-extra/images/extra-services.svg"/>,
# ...

# %%
for img1 in s.find_all('img'):
    print(img1.get('src'))
# Out:
# https://cdn.extra.com/hybris/new_ui_ux/logo/eXtra-logo.svg
# https://cdn.extra.com/hybris/static/assets/prod/202603101550/_ui/responsive/theme-extra/images/spacer_image.gif
# https://cdn.extra.com/hybris/static/assets/prod/202603101550/_ui/responsive/theme-extra/images/spacer_image.gif
# https://cdn.extra.com/hybris/static/assets/prod/202603101550/_ui/responsive/theme-extra/images/jood/jood-logo.svg
# https://cdn.extra.com/hybris/static/assets/prod/202603101550/_ui/responsive/theme-extra/images/baseeta/baseeta-logo-ar.png
# https://cdn.extra.com/hybris/static/assets/prod/202603101550/_ui/responsive/theme-extra/images/extra-services.svg
# https://cdn.extra.com/hybris/static/assets/prod/202603101550/_ui/responsive/theme-extra/images/flag_sa.png
# https://cdn.extra.com/hybris/static/assets/prod/202603101550/_ui/responsive/theme-extra/images/flag_bh.png
# https://cdn.extra.com/hybris/static/assets/prod/202603101550/_ui/responsive/theme-extra/images/flag_sa.png
# ...

# %%
from dotenv import load_dotenv
import os
import requests

load_dotenv()

API_KEY = os.getenv("REMOVE_BG_API_KEY")

response = requests.post(
    "https://api.remove.bg/v1.0/removebg",
    files={"image_file": open("Saud-al-faisal.jpg", "rb")},
    data={"size": "auto"},
    headers={"X-Api-Key": API_KEY},
)

if response.status_code == requests.codes.ok:
    with open("no-bg.png", "wb") as out:
        out.write(response.content)
else:
    print("Error:", response.status_code, response.text)
